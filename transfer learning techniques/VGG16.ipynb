# %%
# import the libraries as shown below

from tensorflow.keras.layers import Input, Lambda, Dense, Flatten,Conv2D
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt

# %%
from keras.layers import Input, Lambda, Dense, Flatten
from keras.models import Model
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt

# re-size all the images to this
IMAGE_SIZE = [224, 224]

train_path = 'C:/Users/Madhur/Desktop/Skin burn analysis (Hackathon)/train'
valid_path = 'C:/Users/Madhur/Desktop/Skin burn analysis (Hackathon)/test'

# add preprocessing layer to the front of VGG
vgg = VGG16(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)

# don't train existing weights
for layer in vgg.layers:
    layer.trainable = False
  

  
  # useful for getting number of classes
folders = glob('train')
  

# our layers - you can add more if you want
x = Flatten()(vgg.output)
# x = Dense(1000, activation='relu')(x)
prediction = Dense(3, activation='softmax')(x)

# create a model object
model = Model(inputs=vgg.input, outputs=prediction)

# view the structure of the model
model.summary()

# tell the model what cost and optimization method to use
model.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)


from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory('C:/Users/Madhur/Desktop/Skin burn analysis (Hackathon)/train',
                                                 target_size = (224, 224),
                                                 batch_size = 32,
                                                 class_mode = 'categorical')

test_set = test_datagen.flow_from_directory('C:/Users/Madhur/Desktop/Skin burn analysis (Hackathon)/test',
                                            target_size = (224, 224),
                                            batch_size = 32,
                                            class_mode = 'categorical')

'''r=model.fit_generator(training_set,
                         samples_per_epoch = 8000,
                         nb_epoch = 5,
                         validation_data = test_set,
                         nb_val_samples = 2000)'''
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 3)                 75267
#
# =================================================================
# Total params: 14,789,955
# Trainable params: 75,267
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Found 920 images belonging to 3 classes.
# Found 540 images belonging to 3 classes.
# 'r=model.fit_generator(training_set,\n                         samples_per_epoch = 8000,\n                         nb_epoch = 5,\n                         validation_data = test_set,\n                         nb_val_samples = 2000)'

# %%
# fit the model
# Run the cell. It will take some time to execute
r = model.fit(
  training_set,
  validation_data=test_set,
  epochs=50,
  steps_per_epoch=len(training_set),
  validation_steps=len(test_set)
)
# Out:
# Epoch 1/50
# 29/29 [==============================] - 205s 7s/step - loss: 1.2116 - accuracy: 0.5478 - val_loss: 0.6144 - val_accuracy: 0.7574
# Epoch 2/50
# 29/29 [==============================] - 175s 6s/step - loss: 0.7578 - accuracy: 0.6565 - val_loss: 0.7585 - val_accuracy: 0.5870
# Epoch 3/50
# 29/29 [==============================] - 164s 6s/step - loss: 0.6015 - accuracy: 0.7522 - val_loss: 0.4481 - val_accuracy: 0.8296
# Epoch 4/50
# 29/29 [==============================] - 206s 7s/step - loss: 0.5001 - accuracy: 0.7967 - val_loss: 0.3679 - val_accuracy: 0.8741
# Epoch 5/50
# 29/29 [==============================] - 221s 8s/step - loss: 0.4282 - accuracy: 0.8348 - val_loss: 0.3216 - val_accuracy: 0.9111
# Epoch 6/50
# 29/29 [==============================] - 199s 7s/step - loss: 0.3919 - accuracy: 0.8620 - val_loss: 0.3970 - val_accuracy: 0.8574
# Epoch 7/50
# 29/29 [==============================] - 201s 7s/step - loss: 0.3750 - accuracy: 0.8696 - val_loss: 0.3227 - val_accuracy: 0.8963
# Epoch 8/50
# 29/29 [==============================] - 240s 8s/step - loss: 0.3385 - accuracy: 0.8880 - val_loss: 0.2540 - val_accuracy: 0.9333
# Epoch 9/50
# 29/29 [==============================] - 232s 8s/step - loss: 0.3182 - accuracy: 0.8880 - val_loss: 0.2178 - val_accuracy: 0.9333
# Epoch 10/50
# 29/29 [==============================] - 200s 7s/step - loss: 0.2853 - accuracy: 0.9033 - val_loss: 0.2778 - val_accuracy: 0.8852
# Epoch 11/50
# 29/29 [==============================] - 198s 7s/step - loss: 0.2762 - accuracy: 0.9152 - val_loss: 0.1981 - val_accuracy: 0.9481
# Epoch 12/50
# 29/29 [==============================] - 199s 7s/step - loss: 0.2322 - accuracy: 0.9261 - val_loss: 0.1937 - val_accuracy: 0.9556
# Epoch 13/50
# 29/29 [==============================] - 196s 7s/step - loss: 0.2468 - accuracy: 0.9185 - val_loss: 0.1717 - val_accuracy: 0.9444
# Epoch 14/50
# 29/29 [==============================] - 199s 7s/step - loss: 0.2268 - accuracy: 0.9293 - val_loss: 0.2393 - val_accuracy: 0.9241
# Epoch 15/50
# 29/29 [==============================] - 197s 7s/step - loss: 0.2757 - accuracy: 0.9022 - val_loss: 0.1807 - val_accuracy: 0.9426
# Epoch 16/50
# 29/29 [==============================] - 197s 7s/step - loss: 0.2091 - accuracy: 0.9424 - val_loss: 0.1951 - val_accuracy: 0.9426
# Epoch 17/50
# 29/29 [==============================] - 202s 7s/step - loss: 0.2067 - accuracy: 0.9457 - val_loss: 0.2098 - val_accuracy: 0.9407
# Epoch 18/50
# 29/29 [==============================] - 217s 8s/step - loss: 0.2066 - accuracy: 0.9293 - val_loss: 0.1552 - val_accuracy: 0.9519
# Epoch 19/50
# 29/29 [==============================] - 219s 8s/step - loss: 0.1871 - accuracy: 0.9326 - val_loss: 0.1320 - val_accuracy: 0.9593
# Epoch 20/50
# 29/29 [==============================] - 225s 8s/step - loss: 0.1782 - accuracy: 0.9457 - val_loss: 0.1678 - val_accuracy: 0.9481
# Epoch 21/50
# 29/29 [==============================] - 252s 9s/step - loss: 0.2599 - accuracy: 0.9054 - val_loss: 0.2541 - val_accuracy: 0.9037
# Epoch 22/50
# 29/29 [==============================] - 238s 8s/step - loss: 0.2058 - accuracy: 0.9261 - val_loss: 0.2338 - val_accuracy: 0.9148
# Epoch 23/50
# 29/29 [==============================] - 224s 8s/step - loss: 0.1789 - accuracy: 0.9489 - val_loss: 0.1327 - val_accuracy: 0.9556
# Epoch 24/50
# 29/29 [==============================] - 229s 8s/step - loss: 0.2002 - accuracy: 0.9380 - val_loss: 0.1970 - val_accuracy: 0.9352
# Epoch 25/50
# 29/29 [==============================] - 225s 8s/step - loss: 0.2012 - accuracy: 0.9348 - val_loss: 0.1783 - val_accuracy: 0.9463
# Epoch 26/50
# 29/29 [==============================] - 224s 8s/step - loss: 0.1517 - accuracy: 0.9500 - val_loss: 0.1401 - val_accuracy: 0.9444
# Epoch 27/50
# 29/29 [==============================] - 224s 8s/step - loss: 0.1762 - accuracy: 0.9446 - val_loss: 0.1200 - val_accuracy: 0.9537
# Epoch 28/50
# 29/29 [==============================] - 226s 8s/step - loss: 0.1303 - accuracy: 0.9609 - val_loss: 0.1188 - val_accuracy: 0.9630
# Epoch 29/50
# 29/29 [==============================] - 223s 8s/step - loss: 0.1554 - accuracy: 0.9413 - val_loss: 0.0977 - val_accuracy: 0.9667
# Epoch 30/50
# 29/29 [==============================] - 222s 8s/step - loss: 0.1493 - accuracy: 0.9543 - val_loss: 0.1452 - val_accuracy: 0.9593
# Epoch 31/50
# 29/29 [==============================] - 222s 8s/step - loss: 0.1706 - accuracy: 0.9391 - val_loss: 0.1373 - val_accuracy: 0.9556
# Epoch 32/50
# 29/29 [==============================] - 236s 8s/step - loss: 0.1453 - accuracy: 0.9500 - val_loss: 0.1207 - val_accuracy: 0.9648
# Epoch 33/50
# 29/29 [==============================] - 257s 9s/step - loss: 0.1360 - accuracy: 0.9576 - val_loss: 0.1669 - val_accuracy: 0.9481
# Epoch 34/50
# 29/29 [==============================] - 257s 9s/step - loss: 0.1387 - accuracy: 0.9500 - val_loss: 0.1036 - val_accuracy: 0.9648
# Epoch 35/50
# 29/29 [==============================] - 257s 9s/step - loss: 0.1294 - accuracy: 0.9565 - val_loss: 0.1393 - val_accuracy: 0.9593
# Epoch 36/50
# 29/29 [==============================] - 242s 8s/step - loss: 0.1465 - accuracy: 0.9467 - val_loss: 0.1001 - val_accuracy: 0.9667
# Epoch 37/50
# 29/29 [==============================] - 184s 6s/step - loss: 0.1073 - accuracy: 0.9674 - val_loss: 0.0934 - val_accuracy: 0.9630
# Epoch 38/50
# 29/29 [==============================] - 183s 6s/step - loss: 0.1211 - accuracy: 0.9609 - val_loss: 0.0811 - val_accuracy: 0.9685
# Epoch 39/50
# 29/29 [==============================] - 182s 6s/step - loss: 0.1357 - accuracy: 0.9576 - val_loss: 0.1065 - val_accuracy: 0.9593
# Epoch 40/50
# 29/29 [==============================] - 183s 6s/step - loss: 0.1462 - accuracy: 0.9543 - val_loss: 0.1110 - val_accuracy: 0.9667
# Epoch 41/50
# 29/29 [==============================] - 182s 6s/step - loss: 0.1329 - accuracy: 0.9576 - val_loss: 0.0932 - val_accuracy: 0.9778
# Epoch 42/50
# 29/29 [==============================] - 181s 6s/step - loss: 0.1509 - accuracy: 0.9500 - val_loss: 0.1025 - val_accuracy: 0.9593
# Epoch 43/50
# 29/29 [==============================] - 182s 6s/step - loss: 0.1336 - accuracy: 0.9533 - val_loss: 0.0824 - val_accuracy: 0.9870
# Epoch 44/50
# 29/29 [==============================] - 182s 6s/step - loss: 0.1777 - accuracy: 0.9348 - val_loss: 0.1283 - val_accuracy: 0.9537
# Epoch 45/50
# 29/29 [==============================] - 189s 7s/step - loss: 0.1322 - accuracy: 0.9543 - val_loss: 0.1233 - val_accuracy: 0.9685
# Epoch 46/50
# 29/29 [==============================] - 205s 7s/step - loss: 0.1331 - accuracy: 0.9620 - val_loss: 0.0725 - val_accuracy: 0.9685
# Epoch 47/50
# 29/29 [==============================] - 203s 7s/step - loss: 0.0981 - accuracy: 0.9696 - val_loss: 0.0672 - val_accuracy: 0.9778
# Epoch 48/50
# 29/29 [==============================] - 198s 7s/step - loss: 0.1210 - accuracy: 0.9587 - val_loss: 0.1064 - val_accuracy: 0.9722
# Epoch 49/50
# 29/29 [==============================] - 189s 7s/step - loss: 0.1100 - accuracy: 0.9609 - val_loss: 0.1572 - val_accuracy: 0.9352
# Epoch 50/50
# 29/29 [==============================] - 190s 7s/step - loss: 0.1636 - accuracy: 0.9457 - val_loss: 0.0747 - val_accuracy: 0.9741

# %%
# plot the loss
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='val loss')
plt.legend()
plt.show()
plt.savefig('LossVal_loss')

# plot the accuracy
plt.plot(r.history['accuracy'], label='train acc')
plt.plot(r.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()
plt.savefig('AccVal_acc')
